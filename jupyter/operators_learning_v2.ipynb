# %%
import numpy as np
import torch
import polars as pl
import seaborn as sns
from pathlib import Path
from tbparse import SummaryReader
from tem import world

version = "v2"

# directory to save results
base_dir = Path(f"~/Dropbox/work/tem/operators/{version}").expanduser()

fig_dir = base_dir / "figs"
fig_dir.mkdir(exist_ok=True, parents=True)

# mounted uFiles directory with design data
design_dir = Path(f"/Volumes/hamllab/data/beh/Operators/{version}/code/operators/design")

start_subj = 201
n_subj = 50
subjects = [f"{number:03d}" for number in range(start_subj, start_subj + n_subj)]
n_runs = 10

# %%
# Set random seeds for reproducibility
np.random.seed(0)
torch.manual_seed(0)

env_files = ["../envs/2x3_env1.json", "../envs/2x3_env2.json"]

sim_dir = base_dir / "simulation"
sim_dir.mkdir(exist_ok=True)

study_dir = sim_dir / "study-1"
while study_dir.exists():
    number = int(study_dir.name.split("-")[1])
    study_dir = sim_dir / f"study-{number + 1}"
study_dir.mkdir()

for subject in subjects:
    raw_file = design_dir / f"sub-{subject}" / f"sub-{subject}_task-learning_design.csv"
    raw = pl.read_csv(raw_file)
    trials = raw.filter(
        ~(
            pl.col("trial_type").str.starts_with("practice")
            | pl.col("trial_type").str.contains("instruction")
            | pl.col("trial_type").str.contains("feedback")
        )
    )
    out_dir = study_dir / f"sub-{subject}"
    out_dir.mkdir()
    design_files = [
        out_dir / f"sub-{subject}_graph-{graph}_design.csv" for graph in [1, 2]
    ]
    trials.filter(graph="graph_1").write_csv(design_files[0])
    trials.filter(graph="graph_2").write_csv(design_files[1])

    out_dir.mkdir(exist_ok=True)
    for run in range(1, n_runs + 1):
        tem_model = world.learn_operators(env_files, design_files, out_dir, subject, run)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 36
#      34 out_dir.mkdir(exist_ok=True)
#      35 for run in range(1, n_runs + 1):
# ---> 36     tem_model = world.learn_operators(env_files, design_files, out_dir, subject, run)
#
# File ~/PycharmProjects/torch_tem/src/tem/world.py:352, in learn_operators(env_files, design_files, out_dir, subject, run)
#     350 walks = walks_operators(design, env, actions)
#     351 design_out_dir = out_dir / f"design-{d}"
# --> 352 tem_model, adam, params, i = learn_walks(
#     353     walks, env, tem_model, adam, params, design_out_dir, i
#     354 )
#     355 torch.save(
#     356     tem_model.state_dict(),
#     357     design_out_dir / f"sub-{subject}_run-{run}_design-{d}_tem.pt",
#     358 )
#     359 torch.save(
#     360     tem_model.hyper,
#     361     design_out_dir / f"sub-{subject}_run-{run}_design-{d}_params.pt",
#     362 )
#
# File ~/PycharmProjects/torch_tem/src/tem/world.py:247, in learn_walks(walks, env, tem_model, adam, params, out_dir, i)
#     244     param_group["lr"] = lr
#     246 # Forward-pass this walk through the network
# --> 247 forward = tem_model(walk, prev_iter)
#     249 # Accumulate loss from forward pass
#     250 loss = torch.tensor(0.0, requires_grad=True)
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:55, in Model.forward(self, walk, prev_iter, prev_M)
#      51     steps = [
#      52         self.init_iteration(g, x, [None for _ in range(len(a))], prev_M)
#      53     ]
#      54 # Perform TEM iteration using transition from previous iteration
# ---> 55 L, M, g_gen, p_gen, x_gen, x_logits, x_inf, g_inf, p_inf = self.iteration(
#      56     x, g, steps[-1].a, steps[-1].M, steps[-1].x_inf, steps[-1].g_inf
#      57 )
#      58 # Store this iteration in iteration object in steps list
#      59 steps.append(
#      60     Iteration(
#      61         g, x, a, L, M, g_gen, p_gen, x_gen, x_logits, x_inf, g_inf, p_inf
#      62     )
#      63 )
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:77, in Model.iteration(self, x, locations, a_prev, M_prev, x_prev, g_prev)
#      73 gt_gen, gt_inf = self.gen_g(a_prev, g_prev, locations)
#      74 # Run inference model: infer grounded location p_inf (hippocampus), abstract
#      75 # location g_inf (entorhinal). Also keep filtered sensory observation (x_inf),
#      76 # and retrieved grounded location p_inf_x
# ---> 77 x_inf, g_inf, p_inf_x, p_inf = self.inference(
#      78     x, locations, M_prev, x_prev, gt_inf
#      79 )
#      80 # Run generative model: since generative model is only used for training
#      81 # purposes, it will generate from *inferred* variables instead of *generated*
#      82 # variables (as it would when used for generation)
#      83 x_gen, x_logits, p_gen = self.generative(M_prev, p_inf, g_inf, gt_gen)
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:124, in Model.inference(self, x, locations, M_prev, x_prev, g_gen)
#     115 p_x = (
#     116     self.attractor(
#     117         x_, M_prev[1], retrieve_it_mask=self.hyper["p_retrieve_mask_inf"]
#    (...)    120     else None
#     121 )
#     122 # Infer abstract location by combining previous abstract location and grounded
#     123 # location retrieved from memory by current sensory experience
# --> 124 g = self.inf_g(p_x, g_gen, x, locations)
#     125 # Prepare abstract location for input to memory by downsampling and weighting
#     126 g_ = self.g2g_(g)
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:566, in Model.inf_g(self, p_x, g_gen, x, locations)
#     560 # Not in paper, but this greatly improves zero-shot inference: provide the
#     561 # uncertainty function of the inferred abstract location with measures of
#     562 # memory quality
#     563 with torch.no_grad():
#     564     # For the first measure, use the grounded location inferred from memory
#     565     # to generate an observation
# --> 566     x_hat, x_hat_logits = self.gen_x(p_x[0])
#     567     # Then calculate the error between the generated observation and the
#     568     # actual observation: if the memory is working well, this error should
#     569     # be small
#     570     err = utils.squared_error(x, x_hat)
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:542, in Model.gen_x(self, p)
#     538     x, logits = self.f_x(p)
#     539     # This is a placeholder! Should be done using reparameterisation trick
#     540     # (like https://blog.evjang.com/2016/11/tutorial-categorical-variational.html)
#     541 else:
# --> 542     x, logits = self.f_x(p)
#     543 # Return one-hot (or almost one-hot...) observation obtained from grounded
#     544 # location, and also the non-softmaxed logits
#     545 return x, logits
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:905, in Model.f_x(self, p)
#     902 x = self.w_x * torch.matmul(p, torch.t(self.hyper["W_tile"][0])) + self.b_x
#     903 # Then we need to decompress the temporally filtered sensory experience into a
#     904 # single current experience prediction
# --> 905 logits = self.f_c_star(x)
#     906 # We'll keep both the logits (domain -inf, inf) and probabilities (domain 0, 1)
#     907 # because both are needed later on
#     908 probability = utils.softmax(logits)
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:913, in Model.f_c_star(self, compressed)
#     911 def f_c_star(self, compressed):
#     912     # Multi layer perceptron to decompress sensory experience at highest frequency
# --> 913     return self.MLP_c_star(compressed)
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/torch_tem/src/tem/model.py:1101, in MLP.forward(self, data)
#    1099     module_output = self.activation[0](module_output)
#    1100 # Pass through second weights from hidden to output layer
# -> 1101 module_output = self.w[n][1](module_output)
#    1102 # Apply output layer activation
#    1103 if self.activation[1] is not None:
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/torch_tem/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
raw_dfs = []
for subject in subjects:
    number = int(subject)
    if number % 2 == 0:
        condition = "AL"
    else:
        condition = "PI"
    for design in ["0", "1"]:
        reader = SummaryReader(str(study_dir / f"sub-{subject}" / f"design-{design}"))
        raw = (
            pl.DataFrame(reader.scalars)
            .with_columns(
                subject=pl.lit(subject),
                condition=pl.lit(condition),
                design=pl.lit(design),
                run=pl.col("value").cum_count().over(pl.col("step")),
            )
        )
        raw_dfs.append(raw)
df = pl.concat(raw_dfs)

# %%
df = df.with_columns(
    pl.col("step").cum_count().over("subject", "run", "design").alias("Trial"),
    pl.col("design").replace({"0": "Initial", "1": "Transfer"}).alias("Graph"),
)

# %%
g = sns.relplot(
    (
        df.filter(pl.col("tag") == "Accuracies/g")
        .with_columns(pl.col("value").rolling_mean(window_size=50).over("subject", "run", "Graph"))
    ),
    x="Trial",
    y="value",
    col="Graph",
    kind="line",
    hue="condition",
)
g.set(ylabel="Structural accuracy")
g.savefig(fig_dir / f"learning_{version}_structure.pdf")

# %%
g = sns.relplot(
    (
        df.filter(pl.col("tag") == "Accuracies/p")
        .with_columns(pl.col("value").rolling_mean(window_size=50).over("subject", "run", "Graph"))
    ),
    x="Trial",
    y="value",
    col="Graph",
    kind="line",
    hue="condition",
)
g.set(ylabel="Perceptual accuracy")
g.savefig(fig_dir / f"learning_{version}_perception.pdf")
